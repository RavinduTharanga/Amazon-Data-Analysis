# %%
import pandas as pd
import os

# Your dataset path
path = "/root/.cache/kagglehub/datasets/hadifariborzi/amazon-books-dataset-20k-books-727k-reviews/versions/2"

# Check files
print(os.listdir(path))

# Load reviews
reviews_path = os.path.join(path, "amazon_books_reviews_sample_20k.csv")
df_reviews = pd.read_csv(reviews_path)

print("Review Columns:")
print(df_reviews.columns.tolist())
print("\nFirst 10 Review Rows:")
display(df_reviews.head(10))

# Load metadata
meta_path = os.path.join(path, "amazon_books_metadata_sample_20k.csv")
df_meta = pd.read_csv(meta_path)

print("\nMetadata Columns:")
print(df_meta.columns.tolist())
print("\nFirst 10 Metadata Rows:")
display(df_meta.head(10))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 path = "/root/.cache/kagglehub/datasets/hadifariborzi/amazon-books-dataset-20k-books-727k-reviews/versions/2"
#       7 # Check files
# ----> 8 print(os.listdir(path))
#      10 # Load reviews
#      11 reviews_path = os.path.join(path, "amazon_books_reviews_sample_20k.csv")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/root/.cache/kagglehub/datasets/hadifariborzi/amazon-books-dataset-20k-books-727k-reviews/versions/2'
