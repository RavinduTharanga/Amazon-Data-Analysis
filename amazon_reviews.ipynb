# %%
from datasets import get_dataset_config_names
import pandas as pd

configs = get_dataset_config_names("McAuley-Lab/Amazon-Reviews-2023")

df = pd.DataFrame(configs, columns=["category"])
df.head()
